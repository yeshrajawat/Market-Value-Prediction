# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("football_data.csv")

# %%
data
# Out:
#       Unnamed: 0            Name  Age  OVA  POT                Team Height  \
# 0              1       19 Malcom   21   82   89        FC Barcelona    172
# 1              2  O. Richards  B   23   74   82   FC Bayern München    174
# 2              3    18 S. Azmoun   22   76   84         Rubin Kazan    186
# 3              4   Arthur Cabral   23   77   85            FC Basel    186
# 4              5        F. Mendy   26   83   86      Real Madrid CF    180
# ...          ...             ...  ...  ...  ...                 ...    ...
# 2995        3045   Nico González   19   69   83        FC Barcelona    188
# 2996        3046     Yeremy Pino   18   75   87       Villarreal CF    172
# 2997        3047         N. Pépé   26   80   81             Arsenal    183
# 2998        3048       R. Cherki   17   73   88  Olympique Lyonnais    176
# 2999        3049       D. Rensch   18   73   85                Ajax    179
#
# ...

# %%
data.drop("Unnamed: 0",axis="columns",inplace=True)

# %%
data.Name[59:71]
# Out:
# 59      E. Camavinga
# 60         19 Malcom
# 61    O. Richards  B
# 62      18 S. Azmoun
# 63     Arthur Cabral
# 64          F. Mendy
# 65    Alexandre Pato
# 66              Gavi
# 67        J. Álvarez
# 68           E. Wahi
# 69        K. Adeyemi
# 70       D. Scarlett
# Name: Name, dtype: object

# %%
data.dropna(inplace=True)

# %%
print(data.dtypes)
# Out:
# Name    object
# Age      int64
# OVA      int64
# POT      int64
# Team    object
#          ...
# PAC     object
# SHO      int64
# PAS      int64
# DRI      int64
# DEF     object
# Length: 63, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Data columns (total 63 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              3000 non-null   object
#  1   Age               3000 non-null   int64
#  2   OVA               3000 non-null   int64
#  3   POT               3000 non-null   int64
#  4   Team              3000 non-null   object
#  5   Height            3000 non-null   object
#  6   Weight            3000 non-null   object
#  7   foot              3000 non-null   object
#  8   BOV               3000 non-null   object
#  9   BP                3000 non-null   object
#  10  Growth            3000 non-null   object
#  11  Value             3000 non-null   float64
#  12  Wage              3000 non-null   float64
#  13  Release Clause    3000 non-null   float64
#  14  Attacking         3000 non-null   object
#  15  Crossing          3000 non-null   int64
# ...

# %%
data['Name'] = data['Name'].astype('str')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Data columns (total 63 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              3000 non-null   object
#  1   Age               3000 non-null   int64
#  2   OVA               3000 non-null   int64
#  3   POT               3000 non-null   int64
#  4   Team              3000 non-null   object
#  5   Height            3000 non-null   object
#  6   Weight            3000 non-null   object
#  7   foot              3000 non-null   object
#  8   BOV               3000 non-null   object
#  9   BP                3000 non-null   object
#  10  Growth            3000 non-null   object
#  11  Value             3000 non-null   float64
#  12  Wage              3000 non-null   float64
#  13  Release Clause    3000 non-null   float64
#  14  Attacking         3000 non-null   object
#  15  Crossing          3000 non-null   int64
# ...

# %%
data
# Out:
#                 Name  Age  OVA  POT                Team Height Weight   foot  \
# 0          19 Malcom   21   82   89        FC Barcelona    172     74   Left
# 1     O. Richards  B   23   74   82   FC Bayern München    174     74   Left
# 2       18 S. Azmoun   22   76   84         Rubin Kazan    186     79  Right
# 3      Arthur Cabral   23   77   85            FC Basel    186     89  Right
# 4           F. Mendy   26   83   86      Real Madrid CF    180     73   Left
# ...              ...  ...  ...  ...                 ...    ...    ...    ...
# 2995   Nico González   19   69   83        FC Barcelona    188     86  Right
# 2996     Yeremy Pino   18   75   87       Villarreal CF    172     60  Right
# 2997         N. Pépé   26   80   81             Arsenal    183     73   Left
# 2998       R. Cherki   17   73   88  Olympique Lyonnais    176     71   Left
# 2999       D. Rensch   18   73   85                Ajax    179     68  Right
#
# ...

# %%
data[data.Height.str.isnumeric()==False]
# Out:
#           Name  Age  OVA  POT             Team        Height Weight  foot  \
# 55    Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 116   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 176   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 235   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 295   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 355   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 415   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 475   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 535   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 595   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 655   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# 715   Y. Demir   18   72   85  FC BarcelonaJun  2022 On Loan  173cm  65kg
# ...

# %%
data.drop(data[data.Height.str.isnumeric()==False].index,inplace=True)

# %%
data
# Out:
#                 Name  Age  OVA  POT                Team Height Weight   foot  \
# 0          19 Malcom   21   82   89        FC Barcelona    172     74   Left
# 1     O. Richards  B   23   74   82   FC Bayern München    174     74   Left
# 2       18 S. Azmoun   22   76   84         Rubin Kazan    186     79  Right
# 3      Arthur Cabral   23   77   85            FC Basel    186     89  Right
# 4           F. Mendy   26   83   86      Real Madrid CF    180     73   Left
# ...              ...  ...  ...  ...                 ...    ...    ...    ...
# 2995   Nico González   19   69   83        FC Barcelona    188     86  Right
# 2996     Yeremy Pino   18   75   87       Villarreal CF    172     60  Right
# 2997         N. Pépé   26   80   81             Arsenal    183     73   Left
# 2998       R. Cherki   17   73   88  Olympique Lyonnais    176     71   Left
# 2999       D. Rensch   18   73   85                Ajax    179     68  Right
#
# ...

# %%
data.reset_index(drop=True)
# Out:
#                 Name  Age  OVA  POT                Team Height Weight   foot  \
# 0          19 Malcom   21   82   89        FC Barcelona    172     74   Left
# 1     O. Richards  B   23   74   82   FC Bayern München    174     74   Left
# 2       18 S. Azmoun   22   76   84         Rubin Kazan    186     79  Right
# 3      Arthur Cabral   23   77   85            FC Basel    186     89  Right
# 4           F. Mendy   26   83   86      Real Madrid CF    180     73   Left
# ...              ...  ...  ...  ...                 ...    ...    ...    ...
# 2945   Nico González   19   69   83        FC Barcelona    188     86  Right
# 2946     Yeremy Pino   18   75   87       Villarreal CF    172     60  Right
# 2947         N. Pépé   26   80   81             Arsenal    183     73   Left
# 2948       R. Cherki   17   73   88  Olympique Lyonnais    176     71   Left
# 2949       D. Rensch   18   73   85                Ajax    179     68  Right
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 0 to 2999
# Data columns (total 63 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              2950 non-null   object
#  1   Age               2950 non-null   int64
#  2   OVA               2950 non-null   int64
#  3   POT               2950 non-null   int64
#  4   Team              2950 non-null   object
#  5   Height            2950 non-null   object
#  6   Weight            2950 non-null   object
#  7   foot              2950 non-null   object
#  8   BOV               2950 non-null   object
#  9   BP                2950 non-null   object
#  10  Growth            2950 non-null   object
#  11  Value             2950 non-null   float64
#  12  Wage              2950 non-null   float64
#  13  Release Clause    2950 non-null   float64
#  14  Attacking         2950 non-null   object
#  15  Crossing          2950 non-null   int64
# ...

# %%
temp_data = data

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 0 to 2999
# Data columns (total 63 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              2950 non-null   object
#  1   Age               2950 non-null   int64
#  2   OVA               2950 non-null   int64
#  3   POT               2950 non-null   int64
#  4   Team              2950 non-null   object
#  5   Height            2950 non-null   object
#  6   Weight            2950 non-null   object
#  7   foot              2950 non-null   object
#  8   BOV               2950 non-null   object
#  9   BP                2950 non-null   object
#  10  Growth            2950 non-null   object
#  11  Value             2950 non-null   float64
#  12  Wage              2950 non-null   float64
#  13  Release Clause    2950 non-null   float64
#  14  Attacking         2950 non-null   object
#  15  Crossing          2950 non-null   int64
# ...

# %%
temp_data[0:60]
# Out:
#                  Name  Age  OVA  POT                      Team Height Weight  \
# 0           19 Malcom   21   82   89              FC Barcelona    172     74
# 1      O. Richards  B   23   74   82         FC Bayern München    174     74
# 2        18 S. Azmoun   22   76   84               Rubin Kazan    186     79
# 3       Arthur Cabral   23   77   85                  FC Basel    186     89
# 4            F. Mendy   26   83   86            Real Madrid CF    180     73
# 5      Alexandre Pato   31   73   73  Orlando City Soccer Club    175     72
# 6                Gavi   16   69   85              FC Barcelona    173     68
# 7          J. Álvarez   21   76   85               River Plate    170     71
# 8             E. Wahi   18   70   81    Montpellier Hérault SC    184     74
# 9          K. Adeyemi   19   72   86      FC Red Bull Salzburg    177     75
# 10        D. Scarlett   17   63   85         Tottenham Hotspur    179     73
# ...

# %%
temp_data.Height = pd.to_numeric(temp_data.Height)
temp_data.Value= pd.to_numeric(temp_data.Value)
temp_data.Age= pd.to_numeric(temp_data.Age)
temp_data.OVA= pd.to_numeric(temp_data.OVA)
temp_data.POT= pd.to_numeric(temp_data.POT)
temp_data.Weight= pd.to_numeric(temp_data.Weight)
temp_data.BOV= pd.to_numeric(temp_data.BOV)
temp_data.Growth= pd.to_numeric(temp_data.Growth)
temp_data.Attacking= pd.to_numeric(temp_data.Attacking)
temp_data.Wage= pd.to_numeric(temp_data.Wage,downcast='float')

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 0 to 2999
# Data columns (total 63 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              2950 non-null   object
#  1   Age               2950 non-null   int64
#  2   OVA               2950 non-null   int64
#  3   POT               2950 non-null   int64
#  4   Team              2950 non-null   object
#  5   Height            2950 non-null   int64
#  6   Weight            2950 non-null   int64
#  7   foot              2950 non-null   object
#  8   BOV               2950 non-null   int64
#  9   BP                2950 non-null   object
#  10  Growth            2950 non-null   int64
#  11  Value             2950 non-null   float64
#  12  Wage              2950 non-null   float32
#  13  Release Clause    2950 non-null   float64
#  14  Attacking         2950 non-null   int64
#  15  Crossing          2950 non-null   int64
# ...

# %%
temp_data.Wage = .001*temp_data.Wage

# %%
temp_data
# Out:
#                 Name  Age  OVA  POT                Team  Height  Weight  \
# 0          19 Malcom   21   82   89        FC Barcelona     172      74
# 1     O. Richards  B   23   74   82   FC Bayern München     174      74
# 2       18 S. Azmoun   22   76   84         Rubin Kazan     186      79
# 3      Arthur Cabral   23   77   85            FC Basel     186      89
# 4           F. Mendy   26   83   86      Real Madrid CF     180      73
# ...              ...  ...  ...  ...                 ...     ...     ...
# 2995   Nico González   19   69   83        FC Barcelona     188      86
# 2996     Yeremy Pino   18   75   87       Villarreal CF     172      60
# 2997         N. Pépé   26   80   81             Arsenal     183      73
# 2998       R. Cherki   17   73   88  Olympique Lyonnais     176      71
# 2999       D. Rensch   18   73   85                Ajax     179      68
#
#        foot  BOV   BP  ...  GK Positioning  GK Reflexes  Total Stats  \
# ...

# %%
temp_data.reset_index(drop=True)
# Out:
#                 Name  Age  OVA  POT                Team  Height  Weight  \
# 0          19 Malcom   21   82   89        FC Barcelona     172      74
# 1     O. Richards  B   23   74   82   FC Bayern München     174      74
# 2       18 S. Azmoun   22   76   84         Rubin Kazan     186      79
# 3      Arthur Cabral   23   77   85            FC Basel     186      89
# 4           F. Mendy   26   83   86      Real Madrid CF     180      73
# ...              ...  ...  ...  ...                 ...     ...     ...
# 2945   Nico González   19   69   83        FC Barcelona     188      86
# 2946     Yeremy Pino   18   75   87       Villarreal CF     172      60
# 2947         N. Pépé   26   80   81             Arsenal     183      73
# 2948       R. Cherki   17   73   88  Olympique Lyonnais     176      71
# 2949       D. Rensch   18   73   85                Ajax     179      68
#
#        foot  BOV   BP  ...  GK Positioning  GK Reflexes  Total Stats  \
# ...

# %%
temp_data.IR = temp_data.IR.str[:-1]

# %%
temp_data.to_csv("football_data_clean.csv",index=False)
